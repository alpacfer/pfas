# %%
import os
import open3d as o3d
import numpy as np
import cv2
from matplotlib import pyplot as plt
import random
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Paths to the folders
depth_folder = "car_challenge/depth"
rgb_folder = "car_challenge/rgb"
output_folder = "car_challenge/point_clouds"
icp_output_folder = "car_challenge/icp_point_clouds"

# Create output folders if they don't exist
os.makedirs(output_folder, exist_ok=True)
os.makedirs(icp_output_folder, exist_ok=True)

# Get sorted lists of file names
depth_images = sorted(os.listdir(depth_folder))
rgb_images = sorted(os.listdir(rgb_folder))

# Lists to hold matching pairs
matching_pairs = []

# Use only images that have a match
min_length = min(len(depth_images), len(rgb_images))
for i in range(min_length):
    depth_name, rgb_name = os.path.splitext(depth_images[i])[0], os.path.splitext(rgb_images[i])[0]
    if depth_name == rgb_name:
        matching_pairs.append((os.path.join(depth_folder, depth_images[i]), os.path.join(rgb_folder, rgb_images[i])))
    else:
        print(f"Mismatch found: {depth_images[i]} (depth) vs {rgb_images[i]} (RGB)")

if matching_pairs:
    print(f"Number of matching pairs: {len(matching_pairs)}")
else:
    print("No matching pairs found.")
# Out:
# Number of matching pairs: 1722

# %%
# Function to create point cloud from images
def create_point_cloud(depth_image, rgb_image, solid_color=None):
    h, w = depth_image.shape
    fx, fy = 525.0, 525.0  # Focal length (example values, adjust accordingly)
    cx, cy = w / 2, h / 2  # Principal point

    points = []
    colors = []

    for v in range(h):
        for u in range(w):
            z = depth_image[v, u] / 1000.0  # Convert depth to meters
            if z == 0:
                continue
            x = (u - cx) * z / fx
            y = (v - cy) * z / fy
            points.append((x, y, z))
            if solid_color is not None:
                colors.append(solid_color)
            else:
                colors.append(rgb_image[v, u] / 255.0)

    # Create Open3D point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(np.array(points))
    point_cloud.colors = o3d.utility.Vector3dVector(np.array(colors))

    return point_cloud

# Function to visualize point clouds
def visualize_point_clouds(point_cloud_ids, solid_colors=False):
    point_clouds = []
    for point_cloud_id in point_cloud_ids:
        point_cloud_path = os.path.join(output_folder, f"point_cloud_{point_cloud_id:04d}.ply")
        if not os.path.exists(point_cloud_path):
            print(f"Point cloud file not found: {point_cloud_path}")
            continue

        # Load point cloud
        point_cloud = o3d.io.read_point_cloud(point_cloud_path)
        if solid_colors:
            # Generate a random color for the point cloud
            color = [random.random(), random.random(), random.random()]
            point_cloud.paint_uniform_color(color)

        print(f"Point cloud {point_cloud_id} has {len(point_cloud.points)} points.")
        point_clouds.append(point_cloud)

    # Visualize point clouds
    if point_clouds:
        o3d.visualization.draw_geometries(point_clouds, window_name="Point Cloud Visualization", width=800, height=600)


# Function to generate point clouds and save them to files with skipping capability
def generate_and_save_point_clouds(skip=1):
    skipped_pairs = matching_pairs[::skip]
    print(f"Processing {len(skipped_pairs)} point clouds out of {len(matching_pairs)} with skip={skip}.")
    for idx, (depth_path, rgb_path) in enumerate(skipped_pairs):
        # Load images
        depth_image = cv2.imread(depth_path, cv2.IMREAD_UNCHANGED)
        rgb_image = cv2.imread(rgb_path, cv2.IMREAD_COLOR)

        # Create point cloud
        point_cloud = create_point_cloud(depth_image, rgb_image)

        # Downsample point cloud if necessary
        num_points = len(point_cloud.points)
        iteration = 0
        while num_points > 20000:
            iteration += 1
            voxel_size = 0.01 + (iteration * 0.01)  # Increase voxel size gradually to ensure reduction
            point_cloud = point_cloud.voxel_down_sample(voxel_size=voxel_size)
            num_points = len(point_cloud.points)
            print(f"Iteration {iteration}: Downsampled point cloud to {num_points} points with voxel size {voxel_size}.")

        # Save point cloud to output folder
        output_path = os.path.join(output_folder, f"point_cloud_{idx * skip:04d}.ply")
        o3d.io.write_point_cloud(output_path, point_cloud)
        print(f"Saved point cloud: {output_path}")
        print(f"Point cloud {idx * skip} has {len(point_cloud.points)} points.")

# %%
# Generate point clouds
generate_and_save_point_clouds(skip=5)
# Out:
# Processing 345 point clouds out of 1722 with skip=5.
# Iteration 1: Downsampled point cloud to 27223 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 12113 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0000.ply
# Point cloud 0 has 12113 points.
# Iteration 1: Downsampled point cloud to 27327 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 12092 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0005.ply
# Point cloud 5 has 12092 points.
# Iteration 1: Downsampled point cloud to 26928 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11895 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0010.ply
# Point cloud 10 has 11895 points.
# Iteration 1: Downsampled point cloud to 26524 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11694 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0015.ply
# Point cloud 15 has 11694 points.
# Iteration 1: Downsampled point cloud to 26553 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11715 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0020.ply
# Point cloud 20 has 11715 points.
# Iteration 1: Downsampled point cloud to 26877 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11799 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0025.ply
# Point cloud 25 has 11799 points.
# Iteration 1: Downsampled point cloud to 26907 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11820 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0030.ply
# Point cloud 30 has 11820 points.
# Iteration 1: Downsampled point cloud to 26533 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11575 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0035.ply
# Point cloud 35 has 11575 points.
# Iteration 1: Downsampled point cloud to 25977 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11270 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0040.ply
# Point cloud 40 has 11270 points.
# Iteration 1: Downsampled point cloud to 25533 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11077 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0045.ply
# Point cloud 45 has 11077 points.
# Iteration 1: Downsampled point cloud to 24493 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 10535 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0050.ply
# Point cloud 50 has 10535 points.
# Iteration 1: Downsampled point cloud to 23267 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 10152 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0055.ply
# Point cloud 55 has 10152 points.
# Iteration 1: Downsampled point cloud to 22902 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9857 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0060.ply
# Point cloud 60 has 9857 points.
# Iteration 1: Downsampled point cloud to 21595 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9289 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0065.ply
# Point cloud 65 has 9289 points.
# Iteration 1: Downsampled point cloud to 21928 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9522 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0070.ply
# Point cloud 70 has 9522 points.
# Iteration 1: Downsampled point cloud to 20632 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 8999 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0075.ply
# Point cloud 75 has 8999 points.
# Iteration 1: Downsampled point cloud to 20581 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 8978 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0080.ply
# Point cloud 80 has 8978 points.
# Iteration 1: Downsampled point cloud to 21804 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9453 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0085.ply
# Point cloud 85 has 9453 points.
# Iteration 1: Downsampled point cloud to 22106 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9690 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0090.ply
# Point cloud 90 has 9690 points.
# Iteration 1: Downsampled point cloud to 21890 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9572 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0095.ply
# Point cloud 95 has 9572 points.
# Iteration 1: Downsampled point cloud to 21149 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 9090 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0100.ply
# Point cloud 100 has 9090 points.
# Iteration 1: Downsampled point cloud to 20447 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 8876 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0105.ply
# Point cloud 105 has 8876 points.
# Iteration 1: Downsampled point cloud to 19511 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0110.ply
# Point cloud 110 has 19511 points.
# Iteration 1: Downsampled point cloud to 19118 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_0115.ply
# Point cloud 115 has 19118 points.
# Iteration 1: Downsampled point cloud to 18920 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_
points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1620.ply
# Point cloud 1620 has 12081 points.
# Iteration 1: Downsampled point cloud to 14834 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1625.ply
# Point cloud 1625 has 14834 points.
# Iteration 1: Downsampled point cloud to 18658 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1630.ply
# Point cloud 1630 has 18658 points.
# Iteration 1: Downsampled point cloud to 21522 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 11380 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1635.ply
# Point cloud 1635 has 11380 points.
# Iteration 1: Downsampled point cloud to 25405 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 13355 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1640.ply
# Point cloud 1640 has 13355 points.
# Iteration 1: Downsampled point cloud to 28803 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 15133 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1645.ply
# Point cloud 1645 has 15133 points.
# Iteration 1: Downsampled point cloud to 30878 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 16082 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1650.ply
# Point cloud 1650 has 16082 points.
# Iteration 1: Downsampled point cloud to 37398 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 19322 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1655.ply
# Point cloud 1655 has 19322 points.
# Iteration 1: Downsampled point cloud to 44040 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 22692 points with voxel size 0.03.
# Iteration 3: Downsampled point cloud to 13855 points with voxel size 0.04.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1660.ply
# Point cloud 1660 has 13855 points.
# Iteration 1: Downsampled point cloud to 46779 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 24577 points with voxel size 0.03.
# Iteration 3: Downsampled point cloud to 15174 points with voxel size 0.04.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1665.ply
# Point cloud 1665 has 15174 points.
# Iteration 1: Downsampled point cloud to 43324 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 22431 points with voxel size 0.03.
# Iteration 3: Downsampled point cloud to 13979 points with voxel size 0.04.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1670.ply
# Point cloud 1670 has 13979 points.
# Iteration 1: Downsampled point cloud to 40917 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 21325 points with voxel size 0.03.
# Iteration 3: Downsampled point cloud to 13001 points with voxel size 0.04.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1675.ply
# Point cloud 1675 has 13001 points.
# Iteration 1: Downsampled point cloud to 38030 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 19249 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1680.ply
# Point cloud 1680 has 19249 points.
# Iteration 1: Downsampled point cloud to 33483 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 16801 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1685.ply
# Point cloud 1685 has 16801 points.
# Iteration 1: Downsampled point cloud to 30080 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 14953 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1690.ply
# Point cloud 1690 has 14953 points.
# Iteration 1: Downsampled point cloud to 29239 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 14556 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1695.ply
# Point cloud 1695 has 14556 points.
# Iteration 1: Downsampled point cloud to 25603 points with voxel size 0.02.
# Iteration 2: Downsampled point cloud to 12687 points with voxel size 0.03.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1700.ply
# Point cloud 1700 has 12687 points.
# Iteration 1: Downsampled point cloud to 18904 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1705.ply
# Point cloud 1705 has 18904 points.
# Iteration 1: Downsampled point cloud to 15335 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1710.ply
# Point cloud 1710 has 15335 points.
# Iteration 1: Downsampled point cloud to 11948 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1715.ply
# Point cloud 1715 has 11948 points.
# Iteration 1: Downsampled point cloud to 9526 points with voxel size 0.02.
# Saved point cloud: car_challenge/point_clouds\point_cloud_1720.ply
# Point cloud 1720 has 9526 points.

# %%
visualize_point_clouds(point_cloud_ids=[1000, 400], solid_colors=True)
# Out:
# Point cloud 1000 has 14593 points.
# Point cloud 400 has 16437 points.

# %%
import os
import numpy as np
import open3d as o3d

# Function to perform pairwise registration using consecutive point clouds
def pairwise_registration_consecutive(skip=1, fitness_threshold=0.7):
    # Paths to the folders
    output_folder = "car_challenge/point_clouds"
    transformation_folder = "car_challenge/transformations"

    # Create folder for saving transformations
    os.makedirs(transformation_folder, exist_ok=True)

    point_cloud_files = sorted(os.listdir(output_folder))[::skip]
    point_cloud_files = [f for f in point_cloud_files if f.endswith('.ply')]
    total_point_clouds = len(point_cloud_files)

    if total_point_clouds < 2:
        print("Not enough point clouds to perform registration.")
        return [], []

    # Initialize transformations list
    transformations = [np.eye(4)]  # The first point cloud is at the origin
    valid_indices = [0]  # Index of point clouds that are successfully registered

    for i in range(1, total_point_clouds):
        source_idx = i - 1  # Use the previous point cloud as the source
        target_idx = i      # Current point cloud as the target

        # Check if transformation file already exists
        transformation_path = os.path.join(transformation_folder, f"transformation_{target_idx:04d}.npy")
        if os.path.exists(transformation_path):
            print(f"Skipping point cloud {target_idx}: Transformation already exists.")
            # Load and append the transformation matrix to the list
            transformation = np.load(transformation_path)
            transformations.append(transformation)
            valid_indices.append(target_idx)
            continue

        source_path = os.path.join(output_folder, point_cloud_files[source_idx])
        target_path = os.path.join(output_folder, point_cloud_files[target_idx])

        source_pcd = o3d.io.read_point_cloud(source_path)
        target_pcd = o3d.io.read_point_cloud(target_path)

        print(f"Registering point cloud {source_idx} to point cloud {target_idx}")

        # Downsample point clouds
        voxel_size = 0.005  # Adjusted voxel size for balance
        source_down = source_pcd.voxel_down_sample(voxel_size)
        target_down = target_pcd.voxel_down_sample(voxel_size)

        # Estimate normals
        radius_normal = 2  # Set a fixed radius
        max_nn_normals = 100  # Increased max_nn
        source_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal, max_nn=max_nn_normals))
        target_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal, max_nn=max_nn_normals))

        # Compute FPFH features
        radius_feature = 0.1  # Set a fixed radius
        max_nn_fpfh = 200  # Increased max_nn
        source_fpfh = o3d.pipelines.registration.compute_fpfh_feature(
            source_down,
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=max_nn_fpfh))
        target_fpfh = o3d.pipelines.registration.compute_fpfh_feature(
            target_down,
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=max_nn_fpfh))

        # Perform RANSAC-based global registration
        distance_threshold = 0.05  # Set a fixed threshold
        result_ransac = o3d.pipelines.registration.registration_ransac_based_on_feature_matching(
            source_down, target_down, source_fpfh, target_fpfh, mutual_filter=True,
            max_correspondence_distance=distance_threshold,
            estimation_method=o3d.pipelines.registration.TransformationEstimationPointToPoint(False),
            ransac_n=4,
            checkers=[
                o3d.pipelines.registration.CorrespondenceCheckerBasedOnEdgeLength(0.9),
                o3d.pipelines.registration.CorrespondenceCheckerBasedOnDistance(distance_threshold)
            ],
            criteria=o3d.pipelines.registration.RANSACConvergenceCriteria(
                max_iteration=2000000, confidence=0.99999)
        )

        # Refine registration with ICP
        threshold_icp = 0.02
        # Re-estimate normals on full point clouds
        radius_normal_full = 0.05
        source_pcd.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal_full, max_nn=max_nn_normals))
        target_pcd.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal_full, max_nn=max_nn_normals))

        result_icp = o3d.pipelines.registration.registration_icp(
            source_pcd, target_pcd, threshold_icp, result_ransac.transformation,
            o3d.pipelines.registration.TransformationEstimationPointToPlane(),
            criteria=o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=10000)
        )

        print(f"Pair {source_idx}-{target_idx} registration result: Fitness - {result_icp.fitness}, Inlier RMSE - {result_icp.inlier_rmse}")

        # Check fitness and decide whether to accept the registration
        if result_icp.fitness >= fitness_threshold:
            # Accumulate transformation
            delta_transformation = result_icp.transformation  # Transformation from source to target
            transformation = delta_transformation @ transformations[source_idx]
            transformations.append(transformation)
            valid_indices.append(target_idx)

            # Save the transformation matrix to file
            np.save(transformation_path, transformation)
            print(f"Transformation saved: {transformation_path}")
        else:
            print(f"Pair {source_idx}-{target_idx} rejected due to low fitness {result_icp.fitness}")
            # Keep the last transformation
            transformations.append(transformations[source_idx])

    return transformations, valid_indices

# %%
transformations, valid_indices = pairwise_registration_consecutive(skip=1, fitness_threshold=0.8)
# Out:
# Registering point cloud 0 to point cloud 1
# Pair 0-1 registration result: Fitness - 0.8015355403285727, Inlier RMSE - 0.011642700344936618
# Transformation saved: car_challenge/transformations\transformation_0001.npy
# Registering point cloud 1 to point cloud 2
# Pair 1-2 registration result: Fitness - 0.8242639761826, Inlier RMSE - 0.012384546366748562
# Transformation saved: car_challenge/transformations\transformation_0002.npy
# Registering point cloud 2 to point cloud 3
# Pair 2-3 registration result: Fitness - 0.8129466162253047, Inlier RMSE - 0.013614344979127533
# Transformation saved: car_challenge/transformations\transformation_0003.npy
# Registering point cloud 3 to point cloud 4
# Pair 3-4 registration result: Fitness - 0.8155464340687532, Inlier RMSE - 0.01300086409364495
# Transformation saved: car_challenge/transformations\transformation_0004.npy
# Registering point cloud 4 to point cloud 5
# Pair 4-5 registration result: Fitness - 0.7770379854886897, Inlier RMSE - 0.013198229939543723
# Pair 4-5 rejected due to low fitness 0.7770379854886897
# Registering point cloud 5 to point cloud 6
# Pair 5-6 registration result: Fitness - 0.783625730994152, Inlier RMSE - 0.012793319493585687
# Pair 5-6 rejected due to low fitness 0.783625730994152
# Registering point cloud 6 to point cloud 7
# Pair 6-7 registration result: Fitness - 0.778595600676819, Inlier RMSE - 0.013028576657617282
# Pair 6-7 rejected due to low fitness 0.778595600676819
# Registering point cloud 7 to point cloud 8
# Pair 7-8 registration result: Fitness - 0.8064794816414687, Inlier RMSE - 0.012179890539762135
# Transformation saved: car_challenge/transformations\transformation_0008.npy
# Registering point cloud 8 to point cloud 9
# Pair 8-9 registration result: Fitness - 0.6716947648624667, Inlier RMSE - 0.013269304399433215
# Pair 8-9 rejected due to low fitness 0.6716947648624667
# Registering point cloud 9 to point cloud 10
# Pair 9-10 registration result: Fitness - 0.6344678161957209, Inlier RMSE - 0.012701111785691593
# Pair 9-10 rejected due to low fitness 0.6344678161957209
# Registering point cloud 10 to point cloud 11
# Pair 10-11 registration result: Fitness - 0.6726150925486474, Inlier RMSE - 0.013086707766712656
# Pair 10-11 rejected due to low fitness 0.6726150925486474
# Registering point cloud 11 to point cloud 12
# Pair 11-12 registration result: Fitness - 0.7035066981875493, Inlier RMSE - 0.012949723473225077
# Pair 11-12 rejected due to low fitness 0.7035066981875493
# Registering point cloud 12 to point cloud 13
# Pair 12-13 registration result: Fitness - 0.7103581211321903, Inlier RMSE - 0.012789585668971796
# Pair 12-13 rejected due to low fitness 0.7103581211321903
# Registering point cloud 13 to point cloud 14
# Pair 13-14 registration result: Fitness - 0.8050382172462052, Inlier RMSE - 0.013317462540981064
# Transformation saved: car_challenge/transformations\transformation_0014.npy
# Registering point cloud 14 to point cloud 15
# Pair 14-15 registration result: Fitness - 0.6896660365469439, Inlier RMSE - 0.013686288311708147
# Pair 14-15 rejected due to low fitness 0.6896660365469439
# Registering point cloud 15 to point cloud 16
# Pair 15-16 registration result: Fitness - 0.7605289476608512, Inlier RMSE - 0.013052589784541975
# Pair 15-16 rejected due to low fitness 0.7605289476608512
# Registering point cloud 16 to point cloud 17
# Pair 16-17 registration result: Fitness - 0.7413677879260414, Inlier RMSE - 0.013202207805256909
# Pair 16-17 rejected due to low fitness 0.7413677879260414
# Registering point cloud 17 to point cloud 18
# Pair 17-18 registration result: Fitness - 0.7613456045699778, Inlier RMSE - 0.013054977102810422
# Pair 17-18 rejected due to low fitness 0.7613456045699778
# Registering point cloud 18 to point cloud 19
# Pair 18-19 registration result: Fitness - 0.779360165118679, Inlier RMSE - 0.013064605337275005
# Pair 18-19 rejected due to low fitness 0.779360165118679
# Registering point cloud 19 to point cloud 20
# Pair 19-20 registration result: Fitness - 0.721479314667781, Inlier RMSE - 0.013507629881921357
# Pair 19-20 rejected due to low fitness 0.721479314667781
# Registering point cloud 20 to point cloud 21
# Pair 20-21 registration result: Fitness - 0.767986798679868, Inlier RMSE - 0.012567737151492541
# Pair 20-21 rejected due to low fitness 0.767986798679868
# Registering point cloud 21 to point cloud 22
# Pair 21-22 registration result: Fitness - 0.824808472284813, Inlier RMSE - 0.010381735653135674
# Transformation saved: car_challenge/transformations\transformation_0022.npy
# Registering point cloud 22 to point cloud 23
# Pair 22-23 registration result: Fitness - 0.8828865768028292, Inlier RMSE - 0.009684804261435288
# Transformation saved: car_challenge/transformations\transformation_0023.npy
# Registering point cloud 23 to point cloud 24
# Pair 23-24 registration result: Fitness - 0.8862851762736688, Inlier RMSE - 0.009639281097055467
# Transformation saved: car_challenge/transformations\transformation_0024.npy
# Registering point cloud 24 to point cloud 25
# Pair 24-25 registration result: Fitness - 0.8334038054968288, Inlier RMSE - 0.009952795839810536
# Transformation saved: car_challenge/transformations\transformation_0025.npy
# Registering point cloud 25 to point cloud 26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 transformations, valid_indices = pairwise_registration_consecutive(skip=1, fitness_threshold=0.8)
#
# Cell In[39], line 66, in pairwise_registration_consecutive(skip, fitness_threshold)
#      62 radius_feature = 0.1  # Set a fixed radius
#      63 max_nn_fpfh = 200  # Increased max_nn
#      64 source_fpfh = o3d.pipelines.registration.compute_fpfh_feature(
#      65     source_down,
# ---> 66     o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=max_nn_fpfh))
#      67 target_fpfh = o3d.pipelines.registration.compute_fpfh_feature(
#      68     target_down,
#      69     o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=max_nn_fpfh))
#      71 # Perform RANSAC-based global registration
#
# KeyboardInterrupt:

# %%
import os
import open3d as o3d
import numpy as np

# Function to merge point clouds using saved transformations
def merge_point_clouds_filtered(skip=1):
    # Paths to the folders
    output_folder = "car_challenge/point_clouds"
    icp_output_folder = "car_challenge/icp_point_clouds"
    transformation_folder = "car_challenge/transformations"

    # Ensure the output folder exists
    os.makedirs(icp_output_folder, exist_ok=True)

    # Get the list of point cloud files
    point_cloud_files = sorted(os.listdir(output_folder))[::skip]
    point_cloud_files = [f for f in point_cloud_files if f.endswith('.ply')]

    merged_pcd = o3d.geometry.PointCloud()

    for idx, pcd_file in enumerate(point_cloud_files):
        pcd_path = os.path.join(output_folder, pcd_file)
        pcd = o3d.io.read_point_cloud(pcd_path)
        
        # Load the corresponding transformation
        transformation_path = os.path.join(transformation_folder, f"transformation_{idx:04d}.npy")
        if os.path.exists(transformation_path):
            transformation = np.load(transformation_path)
            pcd.transform(transformation)
            merged_pcd += pcd
            print(f"Merged point cloud {idx} (file: {pcd_file}) with transformation {transformation_path}")
        else:
            print(f"Transformation file not found for point cloud {idx} (file: {pcd_file}). Skipping.")

    # Optionally, downsample the merged point cloud to reduce size
    voxel_size = 0.02  # Adjust as needed
    merged_pcd = merged_pcd.voxel_down_sample(voxel_size)

    # Save the merged point cloud
    merged_pcd_path = os.path.join(icp_output_folder, "merged_point_cloud_filtered.ply")
    o3d.io.write_point_cloud(merged_pcd_path, merged_pcd)
    print(f"Saved merged point cloud to {merged_pcd_path}")

    # Visualize the merged point cloud
    o3d.visualization.draw_geometries([merged_pcd], window_name="Filtered Merged Point Cloud", width=800, height=600)

# %%
# Merge the point clouds using the transformations and valid indices
merge_point_clouds_filtered(skip=1)
# Out:
# Transformation file not found for point cloud 0 (file: point_cloud_0000.ply). Skipping.
# Merged point cloud 1 (file: point_cloud_0005.ply) with transformation car_challenge/transformations\transformation_0001.npy
# Merged point cloud 2 (file: point_cloud_0010.ply) with transformation car_challenge/transformations\transformation_0002.npy
# Merged point cloud 3 (file: point_cloud_0015.ply) with transformation car_challenge/transformations\transformation_0003.npy
# Merged point cloud 4 (file: point_cloud_0020.ply) with transformation car_challenge/transformations\transformation_0004.npy
# Transformation file not found for point cloud 5 (file: point_cloud_0025.ply). Skipping.
# Transformation file not found for point cloud 6 (file: point_cloud_0030.ply). Skipping.
# Transformation file not found for point cloud 7 (file: point_cloud_0035.ply). Skipping.
# Merged point cloud 8 (file: point_cloud_0040.ply) with transformation car_challenge/transformations\transformation_0008.npy
# Transformation file not found for point cloud 9 (file: point_cloud_0045.ply). Skipping.
# Transformation file not found for point cloud 10 (file: point_cloud_0050.ply). Skipping.
# Transformation file not found for point cloud 11 (file: point_cloud_0055.ply). Skipping.
# Transformation file not found for point cloud 12 (file: point_cloud_0060.ply). Skipping.
# Transformation file not found for point cloud 13 (file: point_cloud_0065.ply). Skipping.
# Merged point cloud 14 (file: point_cloud_0070.ply) with transformation car_challenge/transformations\transformation_0014.npy
# Transformation file not found for point cloud 15 (file: point_cloud_0075.ply). Skipping.
# Transformation file not found for point cloud 16 (file: point_cloud_0080.ply). Skipping.
# Transformation file not found for point cloud 17 (file: point_cloud_0085.ply). Skipping.
# Transformation file not found for point cloud 18 (file: point_cloud_0090.ply). Skipping.
# Transformation file not found for point cloud 19 (file: point_cloud_0095.ply). Skipping.
# Transformation file not found for point cloud 20 (file: point_cloud_0100.ply). Skipping.
# Transformation file not found for point cloud 21 (file: point_cloud_0105.ply). Skipping.
# Merged point cloud 22 (file: point_cloud_0110.ply) with transformation car_challenge/transformations\transformation_0022.npy
# Merged point cloud 23 (file: point_cloud_0115.ply) with transformation car_challenge/transformations\transformation_0023.npy
# Merged point cloud 24 (file: point_cloud_0120.ply) with transformation car_challenge/transformations\transformation_0024.npy
# Merged point cloud 25 (file: point_cloud_0125.ply) with transformation car_challenge/transformations\transformation_0025.npy
# Transformation file not found for point cloud 26 (file: point_cloud_0130.ply). Skipping.
# Transformation file not found for point cloud 27 (file: point_cloud_0135.ply). Skipping.
# Transformation file not found for point cloud 28 (file: point_cloud_0140.ply). Skipping.
# Transformation file not found for point cloud 29 (file: point_cloud_0145.ply). Skipping.
# Transformation file not found for point cloud 30 (file: point_cloud_0150.ply). Skipping.
# Transformation file not found for point cloud 31 (file: point_cloud_0155.ply). Skipping.
# Transformation file not found for point cloud 32 (file: point_cloud_0160.ply). Skipping.
# Transformation file not found for point cloud 33 (file: point_cloud_0165.ply). Skipping.
# Transformation file not found for point cloud 34 (file: point_cloud_0170.ply). Skipping.
# Transformation file not found for point cloud 35 (file: point_cloud_0175.ply). Skipping.
# Transformation file not found for point cloud 36 (file: point_cloud_0180.ply). Skipping.
# Transformation file not found for point cloud 37 (file: point_cloud_0185.ply). Skipping.
# Transformation file not found for point cloud 38 (file: point_cloud_0190.ply). Skipping.
# Transformation file not found for point cloud 39 (file: point_cloud_0195.ply). Skipping.
# Transformation file not found for point cloud 40 (file: point_cloud_0200.ply). Skipping.
# Transformation file not found for point cloud 41 (file: point_cloud_0205.ply). Skipping.
# Transformation file not found for point cloud 42 (file: point_cloud_0210.ply). Skipping.
# Transformation file not found for point cloud 43 (file: point_cloud_0215.ply). Skipping.
# Transformation file not found for point cloud 44 (file: point_cloud_0220.ply). Skipping.
# Transformation file not found for point cloud 45 (file: point_cloud_0225.ply). Skipping.
# Transformation file not found for point cloud 46 (file: point_cloud_0230.ply). Skipping.
# Transformation file not found for point cloud 47 (file: point_cloud_0235.ply). Skipping.
# Transformation file not found for point cloud 48 (file: point_cloud_0240.ply). Skipping.
# Transformation file not found for point cloud 49 (file: point_cloud_0245.ply). Skipping.
# Transformation file not found for point cloud 50 (file: point_cloud_0250.ply). Skipping.
# Transformation file not found for point cloud 51 (file: point_cloud_0255.ply). Skipping.
# Transformation file not found for point cloud 52 (file: point_cloud_0260.ply). Skipping.
# Transformation file not found for point cloud 53 (file: point_cloud_0265.ply). Skipping.
# Transformation file not found for point cloud 54 (file: point_cloud_0270.ply). Skipping.
# Transformation file not found for point cloud 55 (file: point_cloud_0275.ply). Skipping.
# Transformation file not found for point cloud 56 (file: point_cloud_0280.ply). Skipping.
# Transformation file not found for point cloud 57 (file: point_cloud_0285.ply). Skipping.
# Transformation file not found for point cloud 58 (file: point_cloud_0290.ply). Skipping.
# Transformation file not found for point cloud 59 (file: point_cloud_0295.ply). Skipping.
# Transformation file not found for point cloud 60 (file: point_cloud_0300.ply). Skipping.
# Transformation file not found for point cloud 61 (file: point_cloud_0305.ply). Skipping.
# Transformation file not found for point cloud 62 (file: point_cloud_0310.ply). Skipping.
# Transformation file not found for point cloud 63 (file: point_cloud_0315.ply). Skipping.
# Transformation file not found for point cloud 64 (file: point_cloud_0320.ply). Skipping.
# Transformation file not found for point cloud 65 (file: point_cloud_0325.ply). Skipping.
# Transformation file not found for point cloud 66 (file: point_cloud_0330.ply). Skipping.
# Transformation file not found for point cloud 67 (file: point_cloud_0335.ply). Skipping.
# Transformation file not found for point cloud 68 (file: point_cloud_0340.ply). Skipping.
# Transformation file not found for point cloud 69 (file: point_cloud_0345.ply). Skipping.
# Transformation file not found for point cloud 70 (file: point_cloud_0350.ply). Skipping.
# Transformation file not found for point cloud 71 (file: point_cloud_0355.ply). Skipping.
# Transformation file not found for point cloud 72 (file: point_cloud_0360.ply). Skipping.
# Transformation file not found for point cloud 73 (file: point_cloud_0365.ply). Skipping.
# Transformation file not found for point cloud 74 (file: point_cloud_0370.ply). Skipping.
# Transformation file not found for point cloud 75 (file: point_cloud_0375.ply). Skipping.
# Transformation file not found for point cloud 76 (file: point_cloud_0380.ply). Skipping.
# Transformation file not found for point cloud 77 (file: point_cloud_0385.ply). Skipping.
# Transformation file not found for point cloud 78 (file: point_cloud_0390.ply). Skipping.
# Transformation file not found for point cloud 79 (file: point_cloud_0395.ply). Skipping.
# Transformation file not found for point cloud 80 (file: point_cloud_0400.ply). Skipping.
# Transformation file not found for point cloud 81 (file: point_cloud_0405.ply). Skipping.
# Transformation file not found for point cloud 82 (file: point_cloud_0410.ply). Skipping.
# Transformation file not found for point cloud 83 (file: point_cloud_0415.ply). Skipping.
# Transformation file not found for point cloud 84 (file: point_cloud_0420.ply). Skipping.
# Transformation file not found for point cloud 85 (file: point_cloud_0425.ply). Skipping.
# Transformation file not found for point cloud 86 (file: point_cloud_0430.ply). Skipping.
# Transformation file not found for point cloud 87 (file: point_cloud_0435.ply). Skipping.
# Transformation file not found for point cloud 88 (file: point_cloud_0440.ply). Skipping.
# Transformation file not found for point cloud 89 (file: point_cloud_0445.ply). Skipping.
# Transformation file not found for point cloud 90 (file: point_cloud_0450.ply). Skipping.
# Transformation file not found for point cloud 91 (file: point_cloud_0455.ply). Skipping.
# Transformation file not found for point cloud 92 (file: point_cloud_0460.ply). Skipping.
# Transformation file not found for point cloud 93 (file: point_cloud_0465.ply). Skipping.
# Transformation file not found for point cloud 94 (file: point_cloud_0470.ply). Skipping.
# Transformation file not found for point cloud 95 (file: point_cloud_0475.ply). Skipping.
# Transformation file not found for point cloud 96 (file: point_cloud_0480.ply). Skipping.
# Transformation file not found for point cloud 97 (file: point_cloud_0485.ply). Skipping.
# Transformation file not found for point cloud 98 (file: point_cloud_0490.ply). Skipping.
# Transformation file not found for point cloud 99 (file: point_cloud_0495.ply). Skipping.
# Transformation file not found for point cloud 100 (file: point_cloud_0500.ply). Skipping.
# Transformation file not found for point cloud 101 (file: point_cloud_0505.ply). Skipping.
# Transformation file not found for point cloud 102 (file: point_cloud_0510.ply). Skipping.
# Transformation file not found for point cloud 103 (file: point_cloud_0515.ply). Skipping.
# Transformation file not found for point cloud 104 (file: point_cloud_0520.ply). Skipping.
# Transformation file not found for point cloud 105 (file: point_cloud_0525.ply). Skipping.
# Transformation file not found for point cloud 106 (file: point_cloud_0530.ply). Skipping.
# Transformation file not found for point cloud 107 (file: point_cloud_0535.ply). Skipping.
# Transformation file not found for point cloud 108 (file: point_cloud_0540.ply). Skipping.
# Transformation file not found for point cloud 109 (file: point_cloud_0545.ply). Skipping.
# Transformation file not found for point cloud 110 (file: point_cloud_0550.ply). Skipping.
# Transformation file not found for point cloud 111 (file: point_cloud_0555.ply). Skipping.
# Transformation file not found for point cloud 112 (file: point_cloud_0560.ply). Skipping.
# Transformation file not found for point cloud 113 (file: point_cloud_0565.ply). Skipping.
# Transformation file not found for point cloud 114 (file: point_cloud_0570.ply). Skipping.
# Transformation file not found for point cloud 115 (file: point_cloud_0575.ply). Skipping.
# Transformation file not found for point cloud 116 (file: point_cloud_0580.ply). Skipping.
# Transformation file not found for point cloud 117 (file: point_cloud_0585.ply). Skipping.
# Transformation file not found for point cloud 118 (file: point_cloud_0590.ply). Skipping.
# Transformation file not found for point cloud 119 (file: point_cloud_0595.ply). Skipping.
# Transformation file not found for point cloud 120 (file: point_cloud_0600.ply). Skipping.
# Transformation file not found for point cloud 121 (file: point_cloud_0605.ply). Skipping.
# Transformation file not found for point cloud 122 (file: point_cloud_0610.ply). Skipping.
# Transformation file not found for point cloud 123 (file: point_cloud_0615.ply). Skipping.
# Transformation file not found for point cloud 124 (file: point_cloud_0620.ply). Skipping.
# Transformation file not found for point cloud 125 (file: point_cloud_0625.ply). Skipping.
# Transformation file not found for point cloud 126 (file: point_cloud_0630.ply). Skipping.
# Transformation file not found for point cloud 127 (file: point_cloud_0635.ply). Skipping.
# Transformation file not found for point cloud 128 (file: point_cloud_0640.ply). Skipping.
# Transformation file not found for point cloud 129 (file: point_cloud_0645.ply). Skipping.
# Transformation file not found for point cloud 130 (file: point_cloud_0650.ply). Skipping.
# Transformation file not found for point cloud 131 (file: point_cloud_0655.ply). Skipping.
# Transformation file not found for point cloud 132 (file: point_cloud_0660.ply). Skipping.
# Transformation file not found for point cloud 133 (file: point_cloud_0665.ply). Skipping.
# Transformation file not found for point cloud 134 (file: point_cloud_0670.ply). Skipping.
# Transformation file not found for point cloud 135 (file: point_cloud_0675.ply). Skipping.
# Transformation file not found for point cloud 136 (file: point_cloud_0680.ply). Skipping.
# Transformation file not found for point cloud 137 (file: point_cloud_0685.ply). Skipping.
# Transformation file not found for point cloud 138 (file: point_cloud_0690.ply). Skipping.
# Transformation file not found for point cloud 139 (file: point_cloud_0695.ply). Skipping.
# Transformation file not found for point cloud 140 (file: point_cloud_0700.ply). Skipping.
# Transformation file not found for point cloud 141 (file: point_cloud_0705.ply). Skipping.
# Transformation file not found for point cloud 142 (file: point_cloud_0710.ply). Skipping.
# Transformation file not found for point cloud 143 (file: point_cloud_0715.ply). Skipping.
# Transformation file not found for point cloud 144 (file: point_cloud_0720.ply). Skipping.
# Transformation file not found for point cloud 145 (file: point_cloud_0725.ply). Skipping.
# Transformation file not found for point cloud 146 (file: point_cloud_0730.ply). Skipping.
# Transformation file not found for point cloud 147 (file: point_cloud_0735.ply). Skipping.
# Transformation file not found for point cloud 148 (file: point_cloud_0740.ply). Skipping.
# Transformation file not found for point cloud 149 (file: point_cloud_0745.ply). Skipping.
# Transformation file not found for point cloud 150 (file: point_cloud_0750.ply). Skipping.
# Transformation file not found for point cloud 151 (file: point_cloud_0755.ply). Skipping.
# Transformation file not found for point cloud 152 (file: point_cloud_0760.ply). Skipping.
# Transformation file not found for point cloud 153 (file: point_cloud_0765.ply). Skipping.
# Transformation file not found for point cloud 154 (file: point_cloud_0770.ply). Skipping.
# Transformation file not found for point cloud 155 (file: point_cloud_0775.ply). Skipping.
# Transformation file not found for point cloud 156 (file: point_cloud_0780.ply). Skipping.
# Transformation file not found for point cloud 157 (file: point_cloud_0785.ply). Skipping.
# Transformation file not found for point cloud 158 (file: point_cloud_0790.ply). Skipping.
# Transformation file not found for point cloud 159 (file: point_cloud_0795.ply). Skipping.
# Transformation file not found for point cloud 160 (file: point_cloud_0800.ply). Skipping.
# Transformation file not found for point cloud 161 (file: point_cloud_0805.ply). Skipping.
# Transformation file not found for point cloud 162 (file: point_cloud_0810.ply). Skipping.
# Transformation file not found for point cloud 163 (file: point_cloud_0815.ply). Skipping.
# Transformation file not found for point cloud 164 (file: point_cloud_0820.ply). Skipping.
# Transformation file not found for point cloud 165 (file: point_cloud_0825.ply). Skipping.
# Transformation file not found for point cloud 166 (file: point_cloud_0830.ply). Skipping.
# Transformation file not found for point cloud 167 (file: point_cloud_0835.ply). Skipping.
# Transformation file not found for point cloud 168 (file: point_cloud_0840.ply). Skipping.
# Transformation file not found for point cloud 169 (file: point_cloud_0845.ply). Skipping.
# Transformation file not found for point cloud 170 (file: point_cloud_0850.ply). Skipping.
# Transformation file not found for point cloud 171 (file: point_cloud_0855.ply). Skipping.
# Transformation file not found for point cloud 172 (file: point_cloud_0860.ply). Skipping.
# Transformation file not found for point cloud 173 (file: point_cloud_0865.ply). Skipping.
# Transformation file not found for point cloud 174 (file: point_cloud_0870.ply). Skipping.
# Transformation file not found for point cloud 175 (file: point_cloud_0875.ply). Skipping.
# Transformation file not found for point cloud 176 (file: point_cloud_0880.ply). Skipping.
# Transformation file not found for point cloud 177 (file: point_cloud_0885.ply). Skipping.
# Transformation file not found for point cloud 178 (file: point_cloud_0890.ply). Skipping.
# Transformation file not found for point cloud 179 (file: point_cloud_0895.ply). Skipping.
# Transformation file not found for point cloud 180 (file: point_cloud_0900.ply). Skipping.
# Transformation file not found for point cloud 181 (file: point_cloud_0905.ply). Skipping.
# Transformation file not found for point cloud 182 (file: point_cloud_0910.ply). Skipping.
# Transformation file not found for point cloud 183 (file: point_cloud_0915.ply). Skipping.
# Transformation file not found for point cloud 184 (file: point_cloud_0920.ply). Skipping.
# Transformation file not found for point cloud 185 (file: point_cloud_0925.ply). Skipping.
# Transformation file not found for point cloud 186 (file: point_cloud_0930.ply). Skipping.
# Transformation file not found for point cloud 187 (file: point_cloud_0935.ply). Skipping.
# Transformation file not found for point cloud 188 (file: point_cloud_0940.ply). Skipping.
# Transformation file not found for point cloud 189 (file: point_cloud_0945.ply). Skipping.
# Transformation file not found for point cloud 190 (file: point_cloud_0950.ply). Skipping.
# Transformation file not found for point cloud 191 (file: point_cloud_0955.ply). Skipping.
# Transformation file not found for point cloud 192 (file: point_cloud_0960.ply). Skipping.
# Transformation file not found for point cloud 193 (file: point_cloud_0965.ply). Skipping.
# Transformation file not found for point cloud 194 (file: point_cloud_0970.ply). Skipping.
# Transformation file not found for point cloud 195 (file: point_cloud_0975.ply). Skipping.
# Transformation file not found for point cloud 196 (file: point_cloud_0980.ply). Skipping.
# Transformation file not found for point cloud 197 (file: point_cloud_0985.ply). Skipping.
# Transformation file not found for point cloud 198 (file: point_cloud_0990.ply). Skipping.
# Transformation file not found for point cloud 199 (file: point_cloud_0995.ply). Skipping.
# Transformation file not found for point cloud 200 (file: point_cloud_1000.ply). Skipping.
# Transformation file not found for point cloud 201 (file: point_cloud_1005.ply). Skipping.
# Transformation file not found for point cloud 202 (file: point_cloud_1010.ply). Skipping.
# Transformation file not found for point cloud 203 (file: point_cloud_1015.ply). Skipping.
# Transformation file not found for point cloud 204 (file: point_cloud_1020.ply). Skipping.
# Transformation file not found for point cloud 205 (file: point_cloud_1025.ply). Skipping.
# Transformation file not found for point cloud 206 (file: point_cloud_1030.ply). Skipping.
# Transformation file not found for point cloud 207 (file: point_cloud_1035.ply). Skipping.
# Transformation file not found for point cloud 208 (file: point_cloud_1040.ply). Skipping.
# Transformation file not found for point cloud 209 (file: point_cloud_1045.ply). Skipping.
# Transformation file not found for point cloud 210 (file: point_cloud_1050.ply). Skipping.
# Transformation file not found for point cloud 211 (file: point_cloud_1055.ply). Skipping.
# Transformation file not found for point cloud 212 (file: point_cloud_1060.ply). Skipping.
# Transformation file not found for point cloud 213 (file: point_cloud_1065.ply). Skipping.
# Transformation file not found for point cloud 214 (file: point_cloud_1070.ply). Skipping.
# Transformation file not found for point cloud 215 (file: point_cloud_1075.ply). Skipping.
# Transformation file not found for point cloud 216 (file: point_cloud_1080.ply). Skipping.
# Transformation file not found for point cloud 217 (file: point_cloud_1085.ply). Skipping.
# Transformation file not found for point cloud 218 (file: point_cloud_1090.ply). Skipping.
# Transformation file not found for point cloud 219 (file: point_cloud_1095.ply). Skipping.
# Transformation file not found for point cloud 220 (file: point_cloud_1100.ply). Skipping.
# Transformation file not found for point cloud 221 (file: point_cloud_1105.ply). Skipping.
# Transformation file not found for point cloud 222 (file: point_cloud_1110.ply). Skipping.
# Transformation file not found for point cloud 223 (file: point_cloud_1115.ply). Skipping.
# Transformation file not found for point cloud 224 (file: point_cloud_1120.ply). Skipping.
# Transformation file not found for point cloud 225 (file: point_cloud_1125.ply). Skipping.
# Transformation file not found for point cloud 226 (file: point_cloud_1130.ply). Skipping.
# Transformation file not found for point cloud 227 (file: point_cloud_1135.ply). Skipping.
# Transformation file not found for point cloud 228 (file: point_cloud_1140.ply). Skipping.
# Transformation file not found for point cloud 229 (file: point_cloud_1145.ply). Skipping.
# Transformation file not found for point cloud 230 (file: point_cloud_1150.ply). Skipping.
# Transformation file not found for point cloud 231 (file: point_cloud_1155.ply). Skipping.
# Transformation file not found for point cloud 232 (file: point_cloud_1160.ply). Skipping.
# Transformation file not found for point cloud 233 (file: point_cloud_1165.ply). Skipping.
# Transformation file not found for point cloud 234 (file: point_cloud_1170.ply). Skipping.
# Transformation file not found for point cloud 235 (file: point_cloud_1175.ply). Skipping.
# Transformation file not found for point cloud 236 (file: point_cloud_1180.ply). Skipping.
# Transformation file not found for point cloud 237 (file: point_cloud_1185.ply). Skipping.
# Transformation file not found for point cloud 238 (file: point_cloud_1190.ply). Skipping.
# Transformation file not found for point cloud 239 (file: point_cloud_1195.ply). Skipping.
# Transformation file not found for point cloud 240 (file: point_cloud_1200.ply). Skipping.
# Transformation file not found for point cloud 241 (file: point_cloud_1205.ply). Skipping.
# Transformation file not found for point cloud 242 (file: point_cloud_1210.ply). Skipping.
# Transformation file not found for point cloud 243 (file: point_cloud_1215.ply). Skipping.
# Transformation file not found for point cloud 244 (file: point_cloud_1220.ply). Skipping.
# Transformation file not found for point cloud 245 (file: point_cloud_1225.ply). Skipping.
# Transformation file not found for point cloud 246 (file: point_cloud_1230.ply). Skipping.
# Transformation file not found for point cloud 247 (file: point_cloud_1235.ply). Skipping.
# Transformation file not found for point cloud 248 (file: point_cloud_1240.ply). Skipping.
# Transformation file not found for point cloud 249 (file: point_cloud_1245.ply). Skipping.
# Transformation file not found for point cloud 250 (file: point_cloud_1250.ply). Skipping.
# Transformation file not found for point cloud 251 (file: point_cloud_1255.ply). Skipping.
# Transformation file not found for point cloud 252 (file: point_cloud_1260.ply). Skipping.
# Transformation file not found for point cloud 253 (file: point_cloud_1265.ply). Skipping.
# Transformation file not found for point cloud 254 (file: point_cloud_1270.ply). Skipping.
# Transformation file not found for point cloud 255 (file: point_cloud_1275.ply). Skipping.
# Transformation file not found for point cloud 256 (file: point_cloud_1280.ply). Skipping.
# Transformation file not found for point cloud 257 (file: point_cloud_1285.ply). Skipping.
# Transformation file not found for point cloud 258 (file: point_cloud_1290.ply). Skipping.
# Transformation file not found for point cloud 259 (file: point_cloud_1295.ply). Skipping.
# Transformation file not found for point cloud 260 (file: point_cloud_1300.ply). Skipping.
# Transformation file not found for point cloud 261 (file: point_cloud_1305.ply). Skipping.
# Transformation file not found for point cloud 262 (file: point_cloud_1310.ply). Skipping.
# Transformation file not found for point cloud 263 (file: point_cloud_1315.ply). Skipping.
# Transformation file not found for point cloud 264 (file: point_cloud_1320.ply). Skipping.
# Transformation file not found for point cloud 265 (file: point_cloud_1325.ply). Skipping.
# Transformation file not found for point cloud 266 (file: point_cloud_1330.ply). Skipping.
# Transformation file not found for point cloud 267 (file: point_cloud_1335.ply). Skipping.
# Transformation file not found for point cloud 268 (file: point_cloud_1340.ply). Skipping.
# Transformation file not found for point cloud 269 (file: point_cloud_1345.ply). Skipping.
# Transformation file not found for point cloud 270 (file: point_cloud_1350.ply). Skipping.
# Transformation file not found for point cloud 271 (file: point_cloud_1355.ply). Skipping.
# Transformation file not found for point cloud 272 (file: point_cloud_1360.ply). Skipping.
# Transformation file not found for point cloud 273 (file: point_cloud_1365.ply). Skipping.
# Transformation file not found for point cloud 274 (file: point_cloud_1370.ply). Skipping.
# Transformation file not found for point cloud 275 (file: point_cloud_1375.ply). Skipping.
# Transformation file not found for point cloud 276 (file: point_cloud_1380.ply). Skipping.
# Transformation file not found for point cloud 277 (file: point_cloud_1385.ply). Skipping.
# Transformation file not found for point cloud 278 (file: point_cloud_1390.ply). Skipping.
# Transformation file not found for point cloud 279 (file: point_cloud_1395.ply). Skipping.
# Transformation file not found for point cloud 280 (file: point_cloud_1400.ply). Skipping.
# Transformation file not found for point cloud 281 (file: point_cloud_1405.ply). Skipping.
# Transformation file not found for point cloud 282 (file: point_cloud_1410.ply). Skipping.
# Transformation file not found for point cloud 283 (file: point_cloud_1415.ply). Skipping.
# Transformation file not found for point cloud 284 (file: point_cloud_1420.ply). Skipping.
# Transformation file not found for point cloud 285 (file: point_cloud_1425.ply). Skipping.
# Transformation file not found for point cloud 286 (file: point_cloud_1430.ply). Skipping.
# Transformation file not found for point cloud 287 (file: point_cloud_1435.ply). Skipping.
# Transformation file not found for point cloud 288 (file: point_cloud_1440.ply). Skipping.
# Transformation file not found for point cloud 289 (file: point_cloud_1445.ply). Skipping.
# Transformation file not found for point cloud 290 (file: point_cloud_1450.ply). Skipping.
# Transformation file not found for point cloud 291 (file: point_cloud_1455.ply). Skipping.
# Transformation file not found for point cloud 292 (file: point_cloud_1460.ply). Skipping.
# Transformation file not found for point cloud 293 (file: point_cloud_1465.ply). Skipping.
# Transformation file not found for point cloud 294 (file: point_cloud_1470.ply). Skipping.
# Transformation file not found for point cloud 295 (file: point_cloud_1475.ply). Skipping.
# Transformation file not found for point cloud 296 (file: point_cloud_1480.ply). Skipping.
# Transformation file not found for point cloud 297 (file: point_cloud_1485.ply). Skipping.
# Transformation file not found for point cloud 298 (file: point_cloud_1490.ply). Skipping.
# Transformation file not found for point cloud 299 (file: point_cloud_1495.ply). Skipping.
# Transformation file not found for point cloud 300 (file: point_cloud_1500.ply). Skipping.
# Transformation file not found for point cloud 301 (file: point_cloud_1505.ply). Skipping.
# Transformation file not found for point cloud 302 (file: point_cloud_1510.ply). Skipping.
# Transformation file not found for point cloud 303 (file: point_cloud_1515.ply). Skipping.
# Transformation file not found for point cloud 304 (file: point_cloud_1520.ply). Skipping.
# Transformation file not found for point cloud 305 (file: point_cloud_1525.ply). Skipping.
# Transformation file not found for point cloud 306 (file: point_cloud_1530.ply). Skipping.
# Transformation file not found for point cloud 307 (file: point_cloud_1535.ply). Skipping.
# Transformation file not found for point cloud 308 (file: point_cloud_1540.ply). Skipping.
# Transformation file not found for point cloud 309 (file: point_cloud_1545.ply). Skipping.
# Transformation file not found for point cloud 310 (file: point_cloud_1550.ply). Skipping.
# Transformation file not found for point cloud 311 (file: point_cloud_1555.ply). Skipping.
# Transformation file not found for point cloud 312 (file: point_cloud_1560.ply). Skipping.
# Transformation file not found for point cloud 313 (file: point_cloud_1565.ply). Skipping.
# Transformation file not found for point cloud 314 (file: point_cloud_1570.ply). Skipping.
# Transformation file not found for point cloud 315 (file: point_cloud_1575.ply). Skipping.
# Transformation file not found for point cloud 316 (file: point_cloud_1580.ply). Skipping.
# Transformation file not found for point cloud 317 (file: point_cloud_1585.ply). Skipping.
# Transformation file not found for point cloud 318 (file: point_cloud_1590.ply). Skipping.
# Transformation file not found for point cloud 319 (file: point_cloud_1595.ply). Skipping.
# Transformation file not found for point cloud 320 (file: point_cloud_1600.ply). Skipping.
# Transformation file not found for point cloud 321 (file: point_cloud_1605.ply). Skipping.
# Transformation file not found for point cloud 322 (file: point_cloud_1610.ply). Skipping.
# Transformation file not found for point cloud 323 (file: point_cloud_1615.ply). Skipping.
# Transformation file not found for point cloud 324 (file: point_cloud_1620.ply). Skipping.
# Transformation file not found for point cloud 325 (file: point_cloud_1625.ply). Skipping.
# Transformation file not found for point cloud 326 (file: point_cloud_1630.ply). Skipping.
# Transformation file not found for point cloud 327 (file: point_cloud_1635.ply). Skipping.
# Transformation file not found for point cloud 328 (file: point_cloud_1640.ply). Skipping.
# Transformation file not found for point cloud 329 (file: point_cloud_1645.ply). Skipping.
# Transformation file not found for point cloud 330 (file: point_cloud_1650.ply). Skipping.
# Transformation file not found for point cloud 331 (file: point_cloud_1655.ply). Skipping.
# Transformation file not found for point cloud 332 (file: point_cloud_1660.ply). Skipping.
# Transformation file not found for point cloud 333 (file: point_cloud_1665.ply). Skipping.
# Transformation file not found for point cloud 334 (file: point_cloud_1670.ply). Skipping.
# Transformation file not found for point cloud 335 (file: point_cloud_1675.ply). Skipping.
# Transformation file not found for point cloud 336 (file: point_cloud_1680.ply). Skipping.
# Transformation file not found for point cloud 337 (file: point_cloud_1685.ply). Skipping.
# Transformation file not found for point cloud 338 (file: point_cloud_1690.ply). Skipping.
# Transformation file not found for point cloud 339 (file: point_cloud_1695.ply). Skipping.
# Transformation file not found for point cloud 340 (file: point_cloud_1700.ply). Skipping.
# Transformation file not found for point cloud 341 (file: point_cloud_1705.ply). Skipping.
# Transformation file not found for point cloud 342 (file: point_cloud_1710.ply). Skipping.
# Transformation file not found for point cloud 343 (file: point_cloud_1715.ply). Skipping.
# Transformation file not found for point cloud 344 (file: point_cloud_1720.ply). Skipping.
# Saved merged point cloud to car_challenge/icp_point_clouds\merged_point_cloud_filtered.ply

# %%
def visualize_merged_point_cloud():
    merged_pcd_path = os.path.join(icp_output_folder, "merged_point_cloud.ply")
    if not os.path.exists(merged_pcd_path):
        print("Merged point cloud not found.")
        return
    merged_pcd = o3d.io.read_point_cloud(merged_pcd_path)
    o3d.visualization.draw_geometries([merged_pcd], window_name="Merged Point Cloud", width=800, height=600)

visualize_merged_point_cloud()
# Out:
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
